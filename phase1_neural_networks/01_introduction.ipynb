# %% [markdown]
# <a href="https://colab.research.google.com/github/YOUR_USERNAME/YOUR_REPO/blob/main/phase1_neural_networks/01_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 📚 **Quick Start Options:**
#
# ### **Option 1: Run in Google Colab** ☁️ (Recommended!)
# Click the badge above ☝️ to open this notebook in Google Colab (free cloud-based Jupyter)
#
# ### **Option 2: Upload to Colab Manually**
# 1. Go to [https://colab.research.google.com](https://colab.research.google.com)
# 2. Click `File` → `Upload notebook`
# 3. Upload this `.ipynb` file
# 4. Start learning!
#
# ### **Option 3: Run Locally**
# Already running in Jupyter? You're good to go! Just run the cells below.
#
# ---

# %% [markdown]
# # 🎓 Welcome to Your ML Journey!
#
# ## Phase 1, Lesson 1: Introduction to Neural Networks
#
# **Congratulations on starting your machine learning journey!** 🎉
#
# By the end of this notebook, you'll understand:
# - What machine learning actually is (simple explanation!)
# - How neural networks work (with visuals)
# - How to build your first neuron
# - Why this is the foundation for GPT and other AI
#
# **Time needed:** 30-45 minutes
# **Difficulty:** Beginner-friendly ⭐
#
# ---
#
# ### 📖 How to Use This Notebook
#
# 1. Read each cell carefully
# 2. Run code cells by pressing `Shift + Enter`
# 3. Experiment! Change numbers and see what happens
# 4. Don't skip the exercises at the end
#
# Let's begin! 🚀

# %% [markdown]
# ---
#
# ## 🤔 What is Machine Learning?
#
# Think about how you learned to recognize a cat:
# - You weren't given a rule book: "If it has whiskers AND pointy ears AND..."
# - Instead, you saw many cats
# - Your brain learned patterns
# - Now you can recognize cats you've never seen before!
#
# **Machine Learning is the same idea:**
# - Give the computer many examples
# - It finds patterns in the data
# - It can then make predictions on new data
#
# ### Traditional Programming vs Machine Learning
#
# ```
# Traditional Programming:
#   Data + Rules → Computer → Answers
#
# Machine Learning:
#   Data + Answers → Computer → Rules (patterns)
# ```
#
# **Example:**
# - Traditional: "If temperature > 30°C, then 'hot'"
# - ML: Show 1000 examples of temperatures and labels → computer learns the pattern
#
# Pretty cool, right? Let's see this in action!

# %%
# Let's import the libraries we'll need
import numpy as np  # For math operations
import matplotlib.pyplot as plt  # For visualizations

print("✅ Libraries loaded successfully!")
print("You're ready to build your first neural network!")
# Out:
# ✅ Libraries loaded successfully!
# You're ready to build your first neural network!

# %% [markdown]
# ---
#
# ## 🧠 What is a Neuron?
#
# A **neuron** is the basic building block of a neural network. It's inspired by neurons in your brain!
#
# ### How a Neuron Works:
#
# 1. **Takes inputs** (like numbers)
# 2. **Multiplies each input by a weight** (importance)
# 3. **Adds them all up**
# 4. **Adds a bias** (adjustment)
# 5. **Passes through an activation function** (decision maker)
# 6. **Produces an output**
#
# ### The Math (Don't worry, it's simple!):
#
# ```
# output = activation(input₁ × weight₁ + input₂ × weight₂ + ... + bias)
# ```
#
# ### Real-World Analogy:
#
# Imagine deciding whether to go to the beach:
# - **Inputs:** temperature, weather, free time
# - **Weights:** how important each factor is to YOU
# - **Bias:** your general preference for beaches
# - **Output:** Yes/No decision
#
# Let's build this!

# %%
# Let's build a neuron that decides "Should I go to the beach?"

def simple_neuron(temperature, is_sunny, free_time):
    """
    A simple neuron that decides whether to go to the beach.

    Inputs:
        temperature: 0-40 (degrees Celsius)
        is_sunny: 0 (no) or 1 (yes)
        free_time: 0-10 (hours available)

    Output:
        A score (higher = more likely to go)
    """

    # These are our WEIGHTS (how important each factor is)
    weight_temp = 0.3      # Temperature is moderately important
    weight_sunny = 0.5     # Sunshine is very important!
    weight_time = 0.2      # Time is somewhat important

    # This is our BIAS (general preference)
    bias = -5  # We're slightly lazy, so negative bias

    # CALCULATION: weighted sum + bias
    score = (temperature * weight_temp +
             is_sunny * weight_sunny +
             free_time * weight_time +
             bias)

    # ACTIVATION FUNCTION: Convert to Yes/No decision
    # If score > 0, go to beach. Otherwise, stay home.
    decision = "🏖️ GO TO BEACH!" if score > 0 else "🏠 Stay home"

    return score, decision

# Let's test our neuron!
print("=" * 50)
print("BEACH DECISION NEURON")
print("=" * 50)

# Scenario 1: Perfect beach day
score1, decision1 = simple_neuron(temperature=30, is_sunny=1, free_time=5)
print(f"\nScenario 1: 30°C, Sunny, 5 hours free")
print(f"Score: {score1:.2f}")
print(f"Decision: {decision1}")

# Scenario 2: Not a good day
score2, decision2 = simple_neuron(temperature=50, is_sunny=0, free_time=2)
print(f"\nScenario 2: 15°C, Cloudy, 2 hours free")
print(f"Score: {score2:.2f}")
print(f"Decision: {decision2}")

# Scenario 3: Borderline case
score3, decision3 = simple_neuron(temperature=25, is_sunny=1, free_time=3)
print(f"\nScenario 3: 25°C, Sunny, 3 hours free")
print(f"Score: {score3:.2f}")
print(f"Decision: {decision3}")

print("\n" + "=" * 50)
print("🎉 You just ran your first neuron!")
print("=" * 50)
# Out:
# ...
# BEACH DECISION NEURON
# ...
#
# Scenario 1: 30°C, Sunny, 5 hours free
# Score: 5.50
# Decision: 🏖️ GO TO BEACH!
#
# Scenario 2: 15°C, Cloudy, 2 hours free
# Score: 10.40
# Decision: 🏖️ GO TO BEACH!
#
# Scenario 3: 25°C, Sunny, 3 hours free
# Score: 3.60
# Decision: 🏖️ GO TO BEACH!
#
# ...
# 🎉 You just ran your first neuron!
# ...

# %% [markdown]
# ### 💡 Understanding What Just Happened
#
# You just created an **artificial neuron**! Here's what it did:
#
# 1. **Took 3 inputs** (temperature, sunny, time)
# 2. **Multiplied by weights** (importance factors)
# 3. **Added a bias** (personal preference)
# 4. **Made a decision** (go or stay)
#
# This is EXACTLY how neurons work in GPT, ChatGPT, and all AI!
#
# ### 🎮 Your Turn to Experiment!
#
# **Try this:** In the code cell below, change the weights and see how it affects decisions!
# - What if sunshine is SUPER important? (Try weight_sunny = 10)
# - What if you love beaches? (Try bias = 5)
# - What if temperature doesn't matter? (Try weight_temp = 0)

# %%
# EXPERIMENT HERE! Change the weights and bias

def your_custom_neuron(temperature, is_sunny, free_time):
    # 👇 CHANGE THESE VALUES!
    weight_temp = 0.5   # Try different values!
    weight_sunny = 0.6  # Try different values!
    weight_time = 0.5  # Try different values!
    bias = 1          # Try different values!

    score = (temperature * weight_temp +
             is_sunny * weight_sunny +
             free_time * weight_time +
             bias)

    decision = "🏖️ GO TO BEACH!" if score > 16 else "🏠 Stay home"
    return score, decision

# Test your custom neuron
score, decision = your_custom_neuron(temperature=29, is_sunny=0, free_time=2)
print(f"Your Neuron's Decision: {decision}")
print(f"Score: {score:.2f}")
# Out:
# Your Neuron's Decision: 🏖️ GO TO BEACH!
# Score: 16.50

# %% [markdown]
# ---
#
# ## 🌐 What is a Neural Network?
#
# A **neural network** is just many neurons connected together!
#
# ### Structure:
#
# ```
# Input Layer → Hidden Layer(s) → Output Layer
#     ↓              ↓                 ↓
#   Data         Processing         Result
# ```
#
# - **Input Layer:** Receives your data (like an image)
# - **Hidden Layers:** Process and find patterns (the "thinking")
# - **Output Layer:** Produces the answer (like "it's a cat!")
#
# ### Why Multiple Layers?
#
# Each layer learns different levels of complexity:
# - **Layer 1:** Simple features (edges, colors)
# - **Layer 2:** Combinations (eyes, ears)
# - **Layer 3:** Complex patterns (faces, objects)
#
# Let's visualize this!

# %%
# Let's visualize a simple neural network

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.axis('off')

# Define layer positions
layer_names = ['Input\nLayer', 'Hidden\nLayer', 'Output\nLayer']
layer_sizes = [3, 4, 2]  # Number of neurons in each layer
x_positions = [0.2, 0.5, 0.8]

# Draw neurons
neuron_positions = []
colors = ['lightblue', 'lightgreen', 'lightcoral']

for layer_idx, (x, size, color) in enumerate(zip(x_positions, layer_sizes, colors)):
    positions = []
    y_positions = np.linspace(0.2, 0.8, size)

    for y in y_positions:
        circle = mpatches.Circle((x, y), 0.05, color=color, ec='black', linewidth=2)
        ax.add_patch(circle)
        positions.append((x, y))

    neuron_positions.append(positions)

    # Add layer label
    ax.text(x, 0.05, layer_names[layer_idx], ha='center', fontsize=12, fontweight='bold')

# Draw connections between layers
for layer_idx in range(len(neuron_positions) - 1):
    for pos1 in neuron_positions[layer_idx]:
        for pos2 in neuron_positions[layer_idx + 1]:
            ax.plot([pos1[0], pos2[0]], [pos1[1], pos2[1]],
                   'gray', alpha=0.3, linewidth=0.5)

# Add arrows and labels
ax.annotate('', xy=(0.35, 0.9), xytext=(0.25, 0.9),
            arrowprops=dict(arrowstyle='->', lw=2, color='blue'))
ax.text(0.3, 0.95, 'Information flows →', ha='center', fontsize=10, color='blue')

ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_title('Structure of a Neural Network', fontsize=16, fontweight='bold', pad=20)

plt.tight_layout()
plt.show()

print("\n" + "="*60)
print("Each circle is a NEURON (like the one you built!)")
print("Lines show CONNECTIONS (weights)")
print("Information flows left → right")
print("This is how AI 'thinks'!")
print("="*60)
# Out:
# ...
# Each circle is a NEURON (like the one you built!)
# Lines show CONNECTIONS (weights)
# Information flows left → right
# This is how AI 'thinks'!
# ...

# %% [markdown]
# ---
#
# ## 🎯 How Do Neural Networks Learn?
#
# Great question! Here's the process:
#
# ### 1. **Start with Random Weights**
#    - The network doesn't know anything yet
#    - Makes random guesses
#
# ### 2. **Make Predictions**
#    - Feed data through the network
#    - Get an output (probably wrong at first!)
#
# ### 3. **Calculate Error**
#    - Compare prediction to correct answer
#    - How wrong were we?
#
# ### 4. **Adjust Weights**
#    - Change weights to reduce error
#    - This is called **backpropagation**
#
# ### 5. **Repeat Thousands of Times**
#    - Each iteration makes it slightly better
#    - Eventually, it learns patterns!
#
# Let's see this in action with a simple example!

# %%
# Simple learning example: Teach a neuron to multiply by 2

print("🎓 WATCHING A NEURON LEARN\n")
print("Task: Learn that output = input × 2\n")
print("=" * 60)

# Training data (input → correct output)
training_inputs = [1, 2, 3, 4, 5]
training_outputs = [2, 4, 6, 8, 10]  # Just input × 2

# Start with a random weight
weight = 0.5  # Random starting point (wrong!)
learning_rate = 0.01  # How fast to learn

print(f"Starting weight: {weight} (random guess)\n")

# Train for several iterations
errors_over_time = []

for iteration in range(100):
    total_error = 0

    # Go through each training example
    for x, target in zip(training_inputs, training_outputs):
        # 1. Make prediction
        prediction = x * weight

        # 2. Calculate error
        error = target - prediction
        total_error += abs(error)

        # 3. Adjust weight (learning!)
        weight += learning_rate * error * x

    errors_over_time.append(total_error)

    # Print progress every 20 iterations
    if iteration % 20 == 0 or iteration == 99:
        print(f"Iteration {iteration:3d}: Weight = {weight:.3f}, Error = {total_error:.2f}")

print("\n" + "=" * 60)
print(f"✅ LEARNING COMPLETE!")
print(f"Final weight: {weight:.3f}")
print(f"Target weight: 2.000")
print(f"\nThe neuron learned to multiply by 2! 🎉")
print("=" * 60)

# Visualize the learning process
plt.figure(figsize=(10, 5))
plt.plot(errors_over_time, linewidth=2, color='red')
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Total Error', fontsize=12)
plt.title('Watching the Neuron Learn (Error Decreasing Over Time)', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nSee how the error decreased? That's LEARNING! 🧠")
# Out:
# 🎓 WATCHING A NEURON LEARN
#
# Task: Learn that output = input × 2
#
# ...
# Starting weight: 0.5 (random guess)
#
# Iteration   0: Weight = 1.183, Error = 19.38
# Iteration  20: Weight = 2.000, Error = 0.00
# Iteration  40: Weight = 2.000, Error = 0.00
# Iteration  60: Weight = 2.000, Error = 0.00
# Iteration  80: Weight = 2.000, Error = 0.00
# Iteration  99: Weight = 2.000, Error = 0.00
#
# ...
# ✅ LEARNING COMPLETE!
# Final weight: 2.000
# Target weight: 2.000
#
# The neuron learned to multiply by 2! 🎉
# ...
# See how the error decreased? That's LEARNING! 🧠

# %% [markdown]
# ### 🤯 What You Just Witnessed
#
# You just watched a neuron **learn from scratch**!
#
# - Started with a random weight (0.5)
# - Made predictions (mostly wrong at first)
# - Adjusted based on errors
# - Eventually learned the pattern (weight ≈ 2.0)
#
# This is the **EXACT** process that trains:
# - GPT (text generation)
# - Image recognition
# - Self-driving cars
# - Everything in AI!
#
# It's just this simple idea, scaled up with millions of neurons! 🚀

# %% [markdown]
# ---
#
# ## 🎨 Activation Functions: The Decision Makers
#
# Remember our beach neuron? We used a simple rule: if score > 0, go to beach.
#
# That's an **activation function**! It decides when a neuron "fires" (activates).
#
# ### Common Activation Functions:
#
# 1. **Sigmoid** - Squashes values between 0 and 1 (probabilities)
# 2. **ReLU** - Keeps positive values, zeros out negative (most popular!)
# 3. **Tanh** - Squashes between -1 and 1
#
# Let's visualize them!

# %%
# Visualize different activation functions

def sigmoid(x):
    """Sigmoid: Smooth S-curve, outputs 0 to 1"""
    return 1 / (1 + np.exp(-x))

def relu(x):
    """ReLU: Keep positive, zero out negative"""
    return np.maximum(0, x)

def tanh(x):
    """Tanh: Similar to sigmoid but -1 to 1"""
    return np.tanh(x)

# Generate x values
x = np.linspace(-5, 5, 100)

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Sigmoid
axes[0].plot(x, sigmoid(x), linewidth=3, color='blue')
axes[0].set_title('Sigmoid Activation', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Input')
axes[0].set_ylabel('Output')
axes[0].grid(True, alpha=0.3)
axes[0].axhline(y=0, color='k', linewidth=0.5)
axes[0].axvline(x=0, color='k', linewidth=0.5)

# ReLU
axes[1].plot(x, relu(x), linewidth=3, color='green')
axes[1].set_title('ReLU Activation', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Input')
axes[1].set_ylabel('Output')
axes[1].grid(True, alpha=0.3)
axes[1].axhline(y=0, color='k', linewidth=0.5)
axes[1].axvline(x=0, color='k', linewidth=0.5)

# Tanh
axes[2].plot(x, tanh(x), linewidth=3, color='red')
axes[2].set_title('Tanh Activation', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Input')
axes[2].set_ylabel('Output')
axes[2].grid(True, alpha=0.3)
axes[2].axhline(y=0, color='k', linewidth=0.5)
axes[2].axvline(x=0, color='k', linewidth=0.5)

plt.tight_layout()
plt.show()

print("\n📊 Activation Functions Explained:")
print("\nSigmoid: Smooth curve, good for probabilities (0-100%)")
print("ReLU: Simple and fast, most popular! (keeps positive values)")
print("Tanh: Like sigmoid but centered at zero (-1 to +1)")
print("\nWe'll use ReLU a lot in upcoming lessons! 🚀")
# Out:
# 📊 Activation Functions Explained:
#
# Sigmoid: Smooth curve, good for probabilities (0-100%)
# ReLU: Simple and fast, most popular! (keeps positive values)
# Tanh: Like sigmoid but centered at zero (-1 to +1)
#
# We'll use ReLU a lot in upcoming lessons! 🚀

# %% [markdown]
# ---
#
# ## 🎯 Summary: What You Learned Today
#
# Congratulations! You just learned the fundamentals of neural networks! 🎉
#
# ### Key Concepts:
#
# ✅ **Machine Learning** - Computers learning from data, not rules
# ✅ **Neurons** - Basic units that process information (weighted sum + bias)
# ✅ **Neural Networks** - Many neurons connected in layers
# ✅ **Learning** - Adjusting weights to minimize errors
# ✅ **Activation Functions** - Decision makers (ReLU, Sigmoid, Tanh)
#
# ### The Big Picture:
#
# ```
# Every AI system you know uses these concepts:
#   - ChatGPT
#   - Self-driving cars
#   - Image recognition
#   - Voice assistants
#
# They're just bigger versions of what you learned today!
# ```
#
# ### What's Next?
#
# In the next notebook (`02_building_nn.ipynb`), you'll:
# - Build a complete neural network from scratch
# - Implement forward and backward propagation
# - Train it on real problems
# - Understand the math deeply
#
# But first, complete the exercises below! 👇

# %% [markdown]
# ---
#
# ## 💪 Exercises: Test Your Understanding
#
# Complete these exercises to solidify your learning!

# %% [markdown]
# ### Exercise 1: Create Your Own Decision Neuron
#
# **Task:** Build a neuron that decides "Should I watch a movie tonight?"
#
# **Inputs:**
# - `tired_level` (0-10, higher = more tired)
# - `movie_rating` (0-10, higher = better movie)
# - `have_work_tomorrow` (0 = no, 1 = yes)
#
# **Think about:**
# - Which factors are most important? (weights)
# - Do you love or hate movies in general? (bias)
#
# Write your code below! 👇

# %%
# Exercise 1: Your code here!

def movie_decision_neuron(tired_level, movie_rating, have_work_tomorrow):
    """
    Decide whether to watch a movie.
    Return: score and decision ("Watch!" or "Skip")
    """

    # TODO: Set weights for each input
    weight_tired = -0.7# YOUR CODE HERE
    weight_rating = 0.7# YOUR CODE HERE
    weight_work = -0.3# YOUR CODE HERE

    # TODO: Set bias
    bias = 0 # YOUR CODE HERE

    # TODO: Calculate score
    score = (tired_level * weight_tired +
            movie_rating * weight_rating +
            have_work_tomorrow * weight_work + bias)# YOUR CODE HERE

    # TODO: Make decision
    decision = "Watch Movie" if score > 1 else "Do something else" # YOUR CODE HERE

    return score, decision

# Test your neuron
# Uncomment the line below when you're ready:
score, decision = movie_decision_neuron(tired_level=4, movie_rating=7.5, have_work_tomorrow=4)
print(f"Decision: {decision}, Score: {score:.2f}")
# Out:
# Decision: Watch Movie, Score: 1.25

# %% [markdown]
# ### Exercise 2: Understanding Learning
#
# **Question:** Why do you think we need thousands of iterations for learning?
#
# Write your answer below (no wrong answers - just think about it!):

# %% [markdown]
# **Your Answer:**
#
# So we can adjust weights and curve it towards our actual output, since we start with random weights and we dont know what weights we wanna use to predict the answer beforehand(which would be the solution)

# %% [markdown]
# ### Exercise 3: Activation Function Challenge
#
# **Task:** Test different activation functions on the same input.
#
# Complete the code below to see how different functions behave!

# %%
# Exercise 3: Test activation functions

test_values = [-100,-3,-2, -1, 0, 1, 2,3,100]

print("Input\tSigmoid\tReLU\tTanh")
print("=" * 40)

for val in test_values:
    # TODO: Calculate outputs for each activation function
    sig_out = sigmoid(val)# YOUR CODE HERE (use sigmoid(val))
    relu_out = relu(val)# YOUR CODE HERE (use relu(val))
    tanh_out = tanh(val)# YOUR CODE HERE (use tanh(val))

    print(f"{val}\t{sig_out:.3f}\t{relu_out:.3f}\t{tanh_out:.3f}")

# Question: Which activation function keeps negative values? Which zeros them out?
# Out:
# Input	Sigmoid	ReLU	Tanh
# ...
# -100	0.000	0.000	-1.000
# -3	0.047	0.000	-0.995
# -2	0.119	0.000	-0.964
# -1	0.269	0.000	-0.762
# 0	0.500	0.000	0.000
# 1	0.731	1.000	0.762
# 2	0.881	2.000	0.964
# 3	0.953	3.000	0.995
# 100	1.000	100.000	1.000

# %% [markdown]
# ---
#
# ## 🎉 Congratulations!
#
# You've completed your first ML lesson! You now understand:
# - How neural networks think
# - How they learn from data
# - The building blocks of ALL AI systems
#
# ### 🚀 Next Steps:
#
# 1. Make sure you completed the exercises above
# 2. Take a break! Let the concepts sink in
# 3. When ready, open: `02_building_nn.ipynb`
#
# **You're on your way to building GPT!** 🌟
#
# ---
#
# ### 💡 Quick Recap:
#
# ```python
# # This simple equation powers ALL of AI:
# output = activation(inputs × weights + bias)
#
# # Scale this up with millions of neurons and you get:
# # - GPT
# # - Image Recognition
# # - Self-Driving Cars
# # - Everything!
# ```
#
# See you in the next notebook! 👋
